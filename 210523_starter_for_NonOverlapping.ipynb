# %%
# %cd /content/drive/MyDrive/MyProjects/cse257sp21/
# Out:
# /content/drive/MyDrive/MyProjects/cse257sp21

# %% [markdown]
# Set the library version

# %%
# !pip install torchtext==0.1.1
# !pip install torch==0.4.1
# Out:
# ...
#   Found existing installation: torchtext 0.9.1
#     Uninstalling torchtext-0.9.1:
#       Successfully uninstalled torchtext-0.9.1
# ...
#      |████████████████████████████████| 519.5MB 36kB/s
# ERROR: torchvision 0.9.1+cu101 has requirement torch==1.8.1, but you'll have torch 0.4.1 which is incompatible.
# ERROR: fastai 1.0.61 has requirement torch>=1.0.0, but you'll have torch 0.4.1 which is incompatible.
# ...
#   Found existing installation: torch 1.8.1+cu101
#     Uninstalling torch-1.8.1+cu101:
#       Successfully uninstalled torch-1.8.1+cu101
# ...

# %% [markdown]
# ## Non-overlapping Attack with Text Summarization Model

# %%
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src DUC2004 -gpu 0 -gl True -gr True -output nonoverlappingresult.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.7/dist-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.7/dist-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

# %%
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src DUC2004 -gpu 0 -gl True -gr True
# Out:
# Streaming output truncated to the last 5000 lines.
# j: 40, shape: torch.Size([1, 300])
# j: 41, shape: torch.Size([1, 300])
# j: 43, shape: torch.Size([1, 300])
# j: 44, shape: torch.Size([1, 300])
# j: 45, shape: torch.Size([1, 300])
# j: 46, shape: torch.Size([1, 300])
# j: 47, shape: torch.Size([1, 300])
# j: 48, shape: torch.Size([1, 300])
# j: 49, shape: torch.Size([1, 300])
# j: 50, shape: torch.Size([1, 300])
# j: 51, shape: torch.Size([1, 300])
# j: 52, shape: torch.Size([1, 300])
# 9
# 10
# 11
# tensor(0., device='cuda:0') 	 tensor(35.5942, device='cuda:0')
# 12
# 13
# j: 0, shape: torch.Size([1, 300])
# j: 7, shape: torch.Size([1, 300])
# j: 10, shape: torch.Size([1, 300])
# j: 12, shape: torch.Size([1, 300])
# j: 17, shape: torch.Size([1, 300])
# j: 18, shape: torch.Size([1, 300])
# j: 19, shape: torch.Size([1, 300])
# j: 20, shape: torch.Size([1, 300])
# j: 21, shape: torch.Size([1, 300])
# j: 22, shape: torch.Size([1, 300])
# j: 24, shape: torch.Size([1, 300])
# ...

# %%
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_01.txt -gpu 0 -gl True -gr True -output ./NOTS/NOTS_01.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.7/dist-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.7/dist-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

# %%
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_04.txt -gpu 0 -gl True -gr True -output ./NOTS/NOTS_04.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_07.txt -gpu 0 -gl True -gr True -output ./NOTS/NOTS_07.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_10.txt -gpu 0 -gl True -gr True -output ./NOTS/NOTS_10.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_13.txt -gpu 0 -gl True -gr True -output ./NOTS/NOTS_13.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_16.txt -gpu 0 -gl True -gr True -output ./NOTS/NOTS_16.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_19.txt -gpu 0 -gl True -gr True -output ./NOTS/NOTS_19.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_22.txt -gpu 0 -gl True -gr True -output ./NOTS/NOTS_22.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.7/dist-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.7/dist-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

# %%
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_25.txt -gpu 0 -gl True -gr True -output ./NOTS/NOTS_25.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_28.txt -gpu 0 -gl True -gr True -output ./NOTS/NOTS_28.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_31.txt -gpu 0 -gl True -gr True -output ./NOTS/NOTS_31.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_34.txt -gpu 0 -gl True -gr True -output ./NOTS/NOTS_34.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_37.txt -gpu 0 -gl True -gr True -output ./NOTS/NOTS_37.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_40.txt -gpu 0 -gl True -gr True -output ./NOTS/NOTS_40.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_43.txt -gpu 0 -gl True -gr True -output ./NOTS/NOTS_43.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_46.txt -gpu 0 -gl True -gr True -output ./NOTS/NOTS_46.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_49.txt -gpu 0 -gl True -gr True -output ./NOTS/NOTS_49.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.7/dist-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.7/dist-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

# %% [markdown]
# ## Non overlapping Attack with MT

# %%
# !python MTattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src test_2016_flickr_short.en.txt -gpu 0 -gl True -gr True -output nonoverlapping_MT.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.7/dist-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.7/dist-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/MyDrive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/MyDrive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

# %%
# !python MTattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src test_2016_flickr_short.en2.txt -gpu 0 -gl True -gr True -output NOMT_2.txt
# Out:
# python3: can't open file 'MTattack.py': [Errno 2] No such file or directory

# %% [markdown]
# ## Targeted Keywords Attack with Machine Translation model

# %%
# !python MTattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src test_2016_flickr.en -gpu 0 -gl True -gr True -output keyword_MT.txt -tar_dir keyword.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.7/dist-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.7/dist-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

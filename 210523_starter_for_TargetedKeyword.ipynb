# %% [markdown]
# Environment setting
# Ref: https://towardsdatascience.com/conda-google-colab-75f7c867a522

# %%
# %cd /content/drive/MyDrive/MyProjects/cse257sp21/
# Out:
# /content/drive/MyDrive/MyProjects/cse257sp21

# %%
# !python --version
# Out:
# Python 3.7.10

# %%
# !echo $PYTHONPATH
# Out:
# /env/python

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# installing: python-3.6.5-hc3d631a_2 ...
# installing: ca-certificates-2018.03.07-0 ...
# installing: conda-env-2.6.0-h36134e3_1 ...
# installing: libgcc-ng-7.2.0-hdf63c60_3 ...
# installing: libstdcxx-ng-7.2.0-hdf63c60_3 ...
# installing: libffi-3.2.1-hd88cf55_4 ...
# installing: ncurses-6.1-hf484d3e_0 ...
# installing: openssl-1.0.2o-h20670df_0 ...
# installing: tk-8.6.7-hc745277_3 ...
# installing: xz-5.2.4-h14c3975_4 ...
# installing: yaml-0.1.7-had09818_2 ...
# installing: zlib-1.2.11-ha838bed_2 ...
# installing: libedit-3.1.20170329-h6b74fdf_2 ...
# installing: readline-7.0-ha6073c6_4 ...
# installing: sqlite-3.23.1-he433501_0 ...
# installing: asn1crypto-0.24.0-py36_0 ...
# installing: certifi-2018.4.16-py36_0 ...
# installing: chardet-3.0.4-py36h0f667ec_1 ...
# installing: idna-2.6-py36h82fb2a8_1 ...
# installing: pycosat-0.6.3-py36h0a5515d_0 ...
# installing: pycparser-2.18-py36hf9f622e_1 ...
# installing: pysocks-1.6.8-py36_0 ...
# ...

# %%
# !which conda
# !conda --version
# !which python
# !python --version
# Out:
# /usr/local/bin/conda
# conda 4.5.4
# /usr/local/bin/python
# Python 3.6.5 :: Anaconda, Inc.

# %%
import sys
sys.path
# Out:
# ['',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
import sys
_ = (sys.path
        .append("/usr/local/lib/python3.6/site-packages"))

# %%
# !pip install torch==0.4.1
# !pip install torchtext==0.1.1
# Out:
# ...
#     100% |████████████████████████████████| 519.5MB 43kB/s
# tcmalloc: large alloc 1073750016 bytes == 0x5611f5374000 @  0x7fc531bac2a4 0x56119b3d4e25 0x7fc52d376502 0x56119b3cfc20 0x56119b45f67c 0x56119b481cba 0x56119b45970b 0x56119b45f755 0x56119b481cba 0x56119b458a94 0x56119b459941 0x56119b45f755 0x56119b481cba 0x56119b458a94 0x56119b459941 0x56119b45f755 0x56119b481cba 0x56119b458a94 0x56119b459941 0x56119b45f755 0x56119b482a7a 0x56119b45970b 0x56119b45f755 0x56119b481cba 0x56119b458a94 0x56119b459941 0x56119b45f755 0x56119b482a7a 0x56119b458a94 0x56119b459941 0x56119b45f755
# ...
#     100% |████████████████████████████████| 81kB 9.4MB/s
# ...

# %%
# !pip install numpy
# Out:
# ...
#     100% |████████████████████████████████| 13.4MB 3.7MB/s
# ...

# %% [markdown]
# ### sample try

# %%
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src specifictest.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw_sample.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

# %% [markdown]
# ### with 1 keyword

# %% [markdown]
# #### Text Summarization

# %%
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_01.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

# %%
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_02.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_02.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

# %%
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_03.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_03.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

# %%
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_04.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_04.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

# %%
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_05.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_05.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_06.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_06.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_07.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_07.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_08.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_08.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_09.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_09.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_10.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_10.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

# %%
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_11.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_11.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_12.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_12.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_13.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_13.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_14.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_14.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_15.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_15.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_16.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_16.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_17.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_17.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_18.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_18.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_19.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_19.txt
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src ./DUC2004/DUC2004_20.txt -gpu 0 -gl True -gr True -tar_dir keyword1_TS.txt -output ./TSKW/tskw1_new_20.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

# %% [markdown]
# #### Machine Translation

# %%
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 1.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

# %%
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 2.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

# %%
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 3.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_3.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 4.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_4.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 5.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_5.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 6.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_6.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 7.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_7.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 8.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_8.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 9.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_9.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 10.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_10.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 11.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_11.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 12.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_12.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 13.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_13.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 14.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_14.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 15.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_15.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 16.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_16.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 17.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_17.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 18.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_18.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 19.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_19.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 20.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_20.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 21.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_21.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 22.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_22.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 23.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_23.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 24.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_24.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 25.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_25.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 26.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_26.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 27.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_27.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 28.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_28.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 29.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_29.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 30.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_30.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 31.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_31.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 32.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_32.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 33.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_33.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 34.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_34.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 35.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_35.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 36.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_36.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 37.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_37.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 38.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_38.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 39.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_39.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 40.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_40.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 41.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_41.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 42.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_42.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 43.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_43.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 44.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_44.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 45.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_45.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 46.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_46.txt
# Out:
# Streaming output truncated to the last 5000 lines.
#         [   3]])
# lr= 0.1
# [[['Ein', 'Bauarbeiter', 'ist', 'bei', 'einem', 'Hund', 'oder', 'Hund', '<unk>', '.']]]
# [tensor([123], device='cuda:0'), tensor([1101], device='cuda:0'), tensor([6392], device='cuda:0'), tensor([10], device='cuda:0'), tensor([2267], device='cuda:0'), tensor([2465], device='cuda:0'), tensor([858], device='cuda:0'), tensor([31], device='cuda:0'), tensor([9], device='cuda:0'), tensor([4630], device='cuda:0'), tensor([25508], device='cuda:0')]
# A construction worker is driving heavy equipment at a dog 'Or
# ['Ein Bauarbeiter treibt die schwere Ausrüstung an einem Hund an .']
# [tensor([[   2],
#         [7699],
#         [   3]])]
# tensor([[   2],
#         [7699],
#         [   3]])
# lr= 0.1
# [[['Eine', 'Frau', 'läuft', 'nach', 'einem', 'Schlag', 'in', '<unk>', '<unk>', 'den', 'Hund', 'steigt', 'auf', 'ihre', '<unk>']]]
# ...

# %%
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 1.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_1.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 2.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw1_2.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

# %% [markdown]
# ### with 2 keywords

# %%
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 1.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_1.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 2.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_2.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 3.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_3.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 4.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_4.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 5.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_5.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 6.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_6.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 7.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_7.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 8.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_8.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 9.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_9.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 10.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_10.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 11.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_11.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 12.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_12.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 13.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_13.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 14.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_14.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 15.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_15.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

# %%
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 16.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_16.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 17.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_17.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 18.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_18.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 19.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_19.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 20.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_20.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 21.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_21.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 22.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_22.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 23.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_23.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 24.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_24.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 25.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_25.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 26.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_26.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 27.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_27.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 28.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_28.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 29.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_29.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 30.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_30.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 31.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_31.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 32.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_32.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 33.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_33.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 34.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_34.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 35.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_35.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 36.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_36.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 37.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_37.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 38.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_38.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 39.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_39.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 40.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_40.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 41.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_41.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 42.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_42.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 43.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_43.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 44.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_44.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 45.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_45.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 46.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_46.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

# %%
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 22.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_22.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 23.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_23.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 24.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_24.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 25.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_25.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 26.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_26.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 27.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_27.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 28.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_28.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 29.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_29.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 30.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_30.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 31.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_31.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 32.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_32.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 33.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_33.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 34.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_34.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 35.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_35.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 36.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_36.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 37.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_37.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 38.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_38.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 39.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_39.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 40.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_40.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 41.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_41.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 42.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_42.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 43.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_43.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 44.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_44.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 45.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_45.txt
# !python MTKWattack.py -model wmt15-ende_acc_59.25_ppl_7.27_e13.pt -src 46.txt -gpu 0 -gl True -gr True -tar_dir keyword1.txt -output mtkw2_46.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/My Drive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...

# %% [markdown]
# ## Text Summarization

# %%
# !python attack.py -model pretrain_acc_51.41_ppl_12.41_e13.pt -src DUC2004 -gpu 0 -gl True -gr True -tar_dir keyword.txt
# Out:
# Loading model parameters.
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:197: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train), lengths
# /usr/local/lib/python3.6/site-packages/torchtext/data/field.py:198: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   return Variable(arr, volatile=not train)
# /content/drive/MyDrive/MyProjects/cse257sp21/onmt/translate/Translator.py:48: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   def var(a): return Variable(a, volatile=True)
# /content/drive/MyDrive/MyProjects/cse257sp21/onmt/modules/GlobalAttention.py:179: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   align_vectors = self.sm(align.view(batch*targetL, sourceL))
# ...
